# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
from scipy import stats
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('/content/drive/My Drive/Colab Notebooks/2020_Intern_12__T​RI01_Comp/2020_08-03_2020_Intern_12_TRI01_Comp_Parameter_v01.csv', skiprows=1)

print(df.head())
# Out:
#    Whether the scene is able to convey the same message of input text? ???? ????? ??? ????? ??????? ?? ??? ???? ???? ??? ?? ??? ??? ?? ?  ...  How much difficult is the input text to be visualized by human? ?????? ?????? ?????? ???? ?? ???, ????? ??????? ????? ??????? ???
# 0                                                  4                                                                                      ...                                                  0
# 1                                                  3                                                                                      ...                                                  1
# 2                                                  3                                                                                      ...                                                  0
# 3                                                  2                                                                                      ...                                                  3
# 4                                                  4                                                                                      ...                                                  1
#
# [5 rows x 10 columns]

# %%
ques1 = "Whether the scene is able to convey the same message of input text? ???? ????? ??? ????? ??????? ?? ??? ???? ???? ??? ?? ??? ??? ?? ?"
ques2 = "Whether the scene has sufficient number of objects as per the requirement to show the meaning of input text? ????? ??????? ?? ???? ??, ???? ????? ??? ???????? ???????? ?????? ??? ??? ?"
ques3 = "Depending on the input text, whether the objects shown in the scene are properly placed? ????? ??????? ?? ???? ??, ???? ????? ??? ??????? ??? ??????? ???? ??? ?? ??? ??? ????"
ques4 = "Whether the colour mentioned of objects in the scene is appropriate according to Input Text? ????? ??????? ?? ???? ??, ???? ????? ??? ??????? ??? ??????? ?? ??? ?? ??????? ??????? ??? "
ques5 = "Whether the size, shape and texture of mentioned objects in the scene is appropriate according to Input Text? ????? ??????? ?? ???? ??, ???? ????? ??? ??????? ??? ??????? ?? ??????(????) ?? ???? ??????? ???"
ques6 = "Whether the background of scene is chosen properly according to Input Text? ????? ??????? ?? ???? ??, ???? ????? ?? ????????? ??????? ???"
ques7 = "Whether the scene is able to convey any message without taking reference of input text????? ????? ????????? ?? ?? ????? ??????? ?? ??? ???? ?? ??? ???? ?? ???? ???"
ques8 = "Whether the scene composition is realistic? ???? ????? ?????? ???????? ?? ?"
ques9 = "Whether the object orientation are appropriate in the scene? ???? ????? ??? ??????? ?? ?????/????? ??????? ???"
ques10 = "How much difficult is the input text to be visualized by human? ?????? ?????? ?????? ???? ?? ???, ????? ??????? ????? ??????? ???"

# %%
#Have approx 80% i.e. 818 available for training and 20% for testing

fid1_train = df.loc[:817,ques1].values
fid2_train = df.loc[:817,ques2].values
fid3_train = df.loc[:817,ques3].values
fid4_train = df.loc[:817,ques4].values
fid5_train = df.loc[:817,ques5].values
fid6_train = df.loc[:817,ques6].values

int1_train = df.loc[:817,ques7].values
int2_train = df.loc[:817,ques8].values
int3_train = df.loc[:817,ques9].values

subparams_fid_int_train = [fid1_train,fid2_train,fid3_train,fid4_train,fid5_train,fid6_train,int1_train,int2_train,int3_train]

comp_train = df.loc[:817,ques10].values

# %%
#Checking
#print(fid6_train)

# %%
combos_train = [[list(i),list(comp_train)] for i in subparams_fid_int_train]

#Checking
#print(combos_train)

# %%
fid1_test = df.loc[818:,ques1].values
fid2_test = df.loc[818:,ques2].values
fid3_test = df.loc[818:,ques3].values
fid4_test = df.loc[818:,ques4].values
fid5_test = df.loc[818:,ques5].values
fid6_test = df.loc[818:,ques6].values

int1_test = df.loc[818:,ques7].values
int2_test = df.loc[818:,ques8].values
int3_test = df.loc[818:,ques9].values

subparams_fid_int_test = [fid1_test,fid2_test,fid3_test,fid4_test,fid5_test,fid6_test,int1_test,int2_test,int3_test]

comp_test = df.loc[818:,ques10].values

# %%
#Checking
#print(int2_test)

# %%
combos_test = [[list(i),list(comp_train)] for i in subparams_fid_int_test]

#Checking
#print(combos_train)

# %%
def simple_linear_regression(x,y):
    m,c,r = stats.linregress(x,y)[0], stats.linregress(x,y)[1], stats.linregress(x,y)[2]
    return "y = %f * x + %f with r = %f" %(m,c,r)

# %%
def polynomial_regression_order_2(x,y):
    model_fit_o2 = np.poly1d(np.polyfit(x,y,2))
    return "The polynomial fit is \n %s and r^2 score is %f" %(model_fit_o2, r2_score(y,model_fit_o2(x)))

# %%
def polynomial_regression_order_3(x,y):
    model_fit_o3 = np.poly1d(np.polyfit(x,y,3))
    return "The polynomial fit is \n %s and r^2 score is %f" %(model_fit_o3, r2_score(y,model_fit_o3(x)))

# %%
def polynomial_regression_order_4(x,y):
    model_fit_o4 = np.poly1d(np.polyfit(x,y,4))
    return "The polynomial fit is \n %s and r^2 score is %f" %(model_fit_o4, r2_score(y,model_fit_o4(x)))

# %%
def polynomial_regression_order_5(x,y):
    model_fit_o5 = np.poly1d(np.polyfit(x,y,5))
    return "The polynomial fit is \n %s and r^2 score is %f" %(model_fit_o5, r2_score(y,model_fit_o5(x)))

# %%
def polynomial_regression_order_8(x,y):
    model_fit_o8 = np.poly1d(np.polyfit(x,y,8))
    return "The polynomial fit is \n %s and r^2 score is %f" %(model_fit_o8, r2_score(y,model_fit_o8(x)))

# %%
regressions = ["simple_linear_regression","polynomial_regression_order_2","polynomial_regression_order_3","polynomial_regression_order_4", "polynomial_regression_order_5","polynomial_regression_order_8"]

# %%
#These provide a baseline and suggest linear regression is most apt

def execute_func(x,y):
    functions = [simple_linear_regression(x,y), polynomial_regression_order_2(x,y), polynomial_regression_order_3(x,y), polynomial_regression_order_4(x,y), polynomial_regression_order_5(x,y), polynomial_regression_order_8(x,y)]
    #Create a dictionary comprehension
    options = {regressions[i]:functions[i] for i in range(len(regressions))}

    for i in regressions:
        print(options[i])

# %%
for j in range(len(subparams_fid_int_train)):
  if (j < 6):
    print("fid " + str(j+1) + " models \n")
  else:
    print("int " + str(j-5) + " models \n")
  execute_func(combos_train[j][0],combos_train[j][1])

  print("\n")

#Results are a bit messy but important as they imply that linear regression is likely to be more accurate than polynomial regression
# Out:
# fid 1 models
#
# y = -0.581439 * x + 2.767115 with r = -0.709290
# The polynomial fit is
#            2
# -0.03268 x - 0.4173 x + 2.604 and r^2 score is 0.505370
# The polynomial fit is
#           3          2
# 0.05076 x - 0.3798 x + 0.2267 x + 2.358 and r^2 score is 0.511766
# The polynomial fit is
#            4          3         2
# -0.02857 x + 0.2924 x - 1.025 x + 0.7851 x + 2.3 and r^2 score is 0.513072
# The polynomial fit is
#            5           4           3          2
# -0.00582 x + 0.02963 x + 0.08867 x - 0.7343 x + 0.6454 x + 2.3 and r^2 score is 0.513072
# The polynomial fit is
#              8             7             6            5           4
# -5.235e-05 x - 4.709e-05 x + 0.0004509 x + 0.003538 x + 0.01227 x
#             3          2
#  - 0.01694 x - 0.4407 x + 0.465 x + 2.3 and r^2 score is 0.513072
#
#
# fid 2 models
#
# y = -0.591539 * x + 2.896057 with r = -0.655389
# The polynomial fit is
#            2
# -0.02619 x - 0.4514 x + 2.738 and r^2 score is 0.430516
# The polynomial fit is
#           3          2
# 0.07201 x - 0.5533 x + 0.6589 x + 2.143 and r^2 score is 0.438200
# The polynomial fit is
#            4           3          2
# 0.004833 x + 0.03007 x - 0.4358 x + 0.5446 x + 2.167 and r^2 score is 0.438228
# The polynomial fit is
#              5           4            3          2
# -0.0006059 x + 0.01089 x + 0.008861 x - 0.4055 x + 0.53 x + 2.167 and r^2 score is 0.438228
# The polynomial fit is
#              8             7             6            5            4
# -2.174e-05 x - 4.152e-06 x + 0.0002956 x + 0.001895 x + 0.005104 x
#             3          2
#  - 0.02329 x - 0.3122 x + 0.4719 x + 2.167 and r^2 score is 0.438228
#
#
# fid 3 models
#
# y = -0.607938 * x + 2.834331 with r = -0.724779
# The polynomial fit is
#            2
# -0.07082 x - 0.2438 x + 2.451 and r^2 score is 0.534498
# The polynomial fit is
#           3          2
# 0.04192 x - 0.3637 x + 0.3267 x + 2.191 and r^2 score is 0.538320
# The polynomial fit is
#            4          3          2
# -0.01158 x + 0.1408 x - 0.6328 x + 0.572 x + 2.154 and r^2 score is 0.538539
# The polynomial fit is
#             5           4           3          2
# -0.002867 x + 0.01709 x + 0.04041 x - 0.4895 x + 0.5032 x + 2.154 and r^2 score is 0.538539
# The polynomial fit is
#              8             7             6            5            4
# -3.167e-05 x - 2.245e-05 x + 0.0003131 x + 0.002272 x + 0.007082 x
#             3         2
#  - 0.01885 x - 0.323 x + 0.4006 x + 2.154 and r^2 score is 0.538539
#
#
# fid 4 models
#
# y = -0.607038 * x + 2.871761 with r = -0.695061
# The polynomial fit is
#            2
# -0.07628 x - 0.212 x + 2.448 and r^2 score is 0.494151
# The polynomial fit is
#           3          2
# 0.03871 x - 0.3438 x + 0.2945 x + 2.243 and r^2 score is 0.497472
# The polynomial fit is
#            4         3         2
# -0.04662 x + 0.439 x - 1.439 x + 1.281 x + 2.133 and r^2 score is 0.500512
# The polynomial fit is
#             5           4          3         2
# -0.008824 x + 0.04162 x + 0.1302 x - 0.998 x + 1.069 x + 2.133 and r^2 score is 0.500512
# The polynomial fit is
#              8             7             6            5          4
# -7.343e-05 x - 7.093e-05 x + 0.0005947 x + 0.004775 x + 0.0167 x
#             3          2
#  - 0.02153 x - 0.5771 x + 0.8107 x + 2.133 and r^2 score is 0.500512
#
#
# fid 5 models
#
# y = -0.619791 * x + 2.829765 with r = -0.732174
# The polynomial fit is
#           2
# -0.0261 x - 0.4884 x + 2.695 and r^2 score is 0.537420
# The polynomial fit is
#            3           2
# -0.01382 x + 0.06957 x - 0.6716 x + 2.773 and r^2 score is 0.537883
# The polynomial fit is
#           4          3          2
# 0.01446 x - 0.1369 x + 0.4026 x - 0.9694 x + 2.812 and r^2 score is 0.538240
# The polynomial fit is
#            5           4           3          2
# 0.002743 x - 0.01297 x - 0.04087 x + 0.2655 x - 0.9036 x + 2.812 and r^2 score is 0.538240
# The polynomial fit is
#             8             7             6            5            4
# 2.289e-05 x + 2.154e-05 x - 0.0001872 x - 0.001476 x - 0.005081 x
#              3          2
#  + 0.005515 x + 0.1359 x - 0.8239 x + 2.813 and r^2 score is 0.538240
#
#
# fid 6 models
#
# y = -0.612940 * x + 2.937449 with r = -0.706373
# The polynomial fit is
#            2
# -0.08769 x - 0.1605 x + 2.462 and r^2 score is 0.513259
# The polynomial fit is
#           3          2
# 0.02399 x - 0.2558 x + 0.1645 x + 2.326 and r^2 score is 0.514470
# The polynomial fit is
#            4          3          2
# -0.01687 x + 0.1675 x - 0.6422 x + 0.5042 x + 2.286 and r^2 score is 0.514846
# The polynomial fit is
#            5           4           3          2
# -0.00341 x + 0.01723 x + 0.04809 x - 0.4717 x + 0.4223 x + 2.286 and r^2 score is 0.514846
# The polynomial fit is
#              8             7             6            5            4
# -3.143e-05 x - 2.718e-05 x + 0.0002762 x + 0.002118 x + 0.006968 x
#             3          2
#  - 0.01484 x - 0.2968 x + 0.3149 x + 2.286 and r^2 score is 0.514846
#
#
# int 1 models
#
# y = -0.566825 * x + 2.684401 with r = -0.693812
# The polynomial fit is
#            2
# -0.01321 x - 0.5009 x + 2.619 and r^2 score is 0.481735
# The polynomial fit is
#            3           2
# 0.004946 x - 0.04734 x - 0.436 x + 2.592 and r^2 score is 0.481796
# The polynomial fit is
#            4          3         2
# -0.03772 x + 0.3233 x - 0.897 x + 0.3042 x + 2.5 and r^2 score is 0.484256
# The polynomial fit is
#             5           4           3          2
# -0.006468 x + 0.02696 x + 0.09693 x - 0.5736 x + 0.1489 x + 2.5 and r^2 score is 0.484256
# The polynomial fit is
#              8             7             6           5           4
# -4.559e-05 x - 5.264e-05 x + 0.0003103 x + 0.00275 x + 0.01058 x
#              3          2
#  - 0.003286 x - 0.2971 x - 0.02042 x + 2.5 and r^2 score is 0.484256
#
#
# int 2 models
#
# y = -0.567973 * x + 2.611339 with r = -0.709015
# The polynomial fit is
#             2
# -0.009347 x - 0.523 x + 2.569 and r^2 score is 0.502919
# The polynomial fit is
#             3           2
# -0.003146 x + 0.01152 x - 0.5598 x + 2.581 and r^2 score is 0.502948
# The polynomial fit is
#             4           3          2
# -0.009011 x + 0.07289 x - 0.1911 x - 0.3862 x + 2.567 and r^2 score is 0.503104
# The polynomial fit is
#             5            4           3          2
# -0.001457 x + 0.005562 x + 0.02189 x - 0.1182 x - 0.4211 x + 2.567 and r^2 score is 0.503104
# The polynomial fit is
#              8             7             6             5           4
# -8.767e-06 x - 1.213e-05 x + 4.693e-05 x + 0.0004928 x + 0.00217 x
#              3           2
#  + 0.001381 x - 0.06177 x - 0.4556 x + 2.567 and r^2 score is 0.503104
#
#
# int 3 models
#
# y = -0.638239 * x + 2.842237 with r = -0.747589
# The polynomial fit is
#            2
# -0.06036 x - 0.3346 x + 2.527 and r^2 score is 0.566009
# The polynomial fit is
#             3           2
# -0.007042 x - 0.01193 x - 0.4268 x + 2.567 and r^2 score is 0.566131
# The polynomial fit is
#            4          3          2
# -0.02345 x + 0.1932 x - 0.5579 x + 0.06866 x + 2.5 and r^2 score is 0.567122
# The polynomial fit is
#             5           4           3          2
# -0.003959 x + 0.01615 x + 0.05466 x - 0.3599 x - 0.02637 x + 2.5 and r^2 score is 0.567122
# The polynomial fit is
#             8             7             6            5            4
# -2.77e-05 x - 3.146e-05 x + 0.0001893 x + 0.001639 x + 0.005993 x
#              3          2
#  - 0.005173 x - 0.1937 x - 0.1284 x + 2.5 and r^2 score is 0.567122
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: RankWarning: Polyfit may be poorly conditioned
#   after removing the cwd from sys.path.

# %%
#Now to build the neural network to try multiple regression - some functions have to be defined

# %%
def round_num_to_nearest_base(x, prec=2, base=0.2):
  return round(base * round(float(x)/base),prec)

# %%
def ReLU(Z):

    #Return ReLU of input value
    A = np.maximum(0,Z)
    
    assert(A.shape == Z.shape)
    
    cache = Z 
    return A, cache

# %%
def ReLU_backward(dA,cache):

    #Implement backward propogation of activation
    
    Z = cache
    dZ = np.array(dA, copy=True) # just converting dz to a correct object.
    
    # When z <= 0, you should set dz to 0 as well. 
    dZ[Z <= 0] = 0
    
    assert (dZ.shape == Z.shape)
    
    return dZ

# %%
def initialise_parameters(layer_dims):
    
    #Random initialisation of Ws and zero initialisation of bias vector

    parameters = {}
    L = len(layer_dims)            # number of layers in the network

    for l in range(1, L):
        parameters['W' + str(l)] = np.random.randn(layer_dims[l],layer_dims[l-1])*0.01
        parameters['b' + str(l)] = np.zeros((layer_dims[l],1))
        
        assert(parameters['W' + str(l)].shape == (layer_dims[l], layer_dims[l-1]))
        assert(parameters['b' + str(l)].shape == (layer_dims[l], 1))

        
    return parameters

# %%
def forward_prop(A, W, b):

    #Implement forward propogation 
    
    Z = np.dot(W,A)+b
    
    assert(Z.shape == (W.shape[0], A.shape[1]))
    cache = (A, W, b)
    
    return Z, cache

# %%
def activation_forward_prop(A_prev, W, b, activation):

    #Activation function step for forward propogation

    if activation == "relu":
        Z, linear_cache = forward_prop(A_prev,W,b)
        A, activation_cache = ReLU(Z)
    
    elif activation == "linear":
        Z, linear_cache = forward_prop(A_prev,W,b)
        A, activation_cache = linear(Z)

    assert (A.shape == (W.shape[0], A_prev.shape[1]))
    cache = (linear_cache, activation_cache)

    return A, cache

# %%
def L_layer_forward_prop(X, parameters):

    #Ensure that forward propogation is done for layer l

    caches = []
    A = X
    L = len(parameters) // 2                  # number of layers in the neural network
    
    for l in range(1, L):
        A_prev = A 
        A, cache = activation_forward_prop(A_prev,parameters['W' + str(l)],parameters['b' + str(l)],activation = "relu")
        caches.append(cache)
    
    AL, cache = activation_forward_prop(A,parameters['W' + str(L)],parameters['b' + str(L)],activation = "relu")
    caches.append(cache)
    
    assert(AL.shape == (1,X.shape[1]))
            
    return AL, caches

# %%
#A mean squared error cost function is good for regression

def cost_func(AL,Y):

    #Implement a mean squared error cost function which is good for regression

    m = Y.shape[1]

    cost = (1/(2*m))*(np.sum(np.square(np.subtract(AL,Y))))
    return cost

# %%
def backward_prop(dZ, cache):

    #Implemenet backward propogation
    
    A_prev, W, b = cache
    m = A_prev.shape[1]

    dW = 1/m*np.dot(dZ,(A_prev.T))
    db = 1/m*(np.sum(dZ,axis=1, keepdims=True))
    dA_prev = np.dot((W.T),dZ)
    
    assert (dA_prev.shape == A_prev.shape)
    assert (dW.shape == W.shape)
    assert (db.shape == b.shape)

    return dA_prev, dW, db

# %%
def activation_backward_prop(dA, cache, activation):

    #The activation step for backward propogation

    linear_cache, activation_cache = cache
    
    if activation == "relu":
        dZ = ReLU_backward(dA,activation_cache)
        dA_prev, dW, db = backward_prop(dZ,linear_cache)
        
    return dA_prev, dW, db

# %%
def L_layer_backward_prop(AL, Y, caches):

    #Ensure that backward propogation is done for layer l
    
    grads = {}
    L = len(caches) # the number of layers
    Y = Y.reshape(AL.shape) # after this line, Y is the same shape as AL
    
    # Initializing the backpropagation
    dAL = (AL-Y) # derivative of mean squared error cost with respect to AL
    
    # Lth layer (RELU -> LINEAR) gradients. Inputs: "dAL, current_cache". Outputs: "grads["dAL-1"], grads["dWL"], grads["dbL"]
    current_cache = caches[L-1]
    grads["dA" + str(L-1)], grads["dW" + str(L)], grads["db" + str(L)] = activation_backward_prop(dAL,current_cache,activation="relu")
    
    # Loop from l=L-2 to l=0
    for l in reversed(range(L-1)):
        # lth layer: (RELU -> LINEAR) gradients.
        current_cache = caches[l]
        dA_prev_temp = grads["dA" + str(l+1)] #dA_prev_temp, dW_temp, db_temp = grads["dA" + str(l+1)], grads["dW" + str(l+2)], grads["db" + str(l+2)]
        grads["dA" + str(l)] = activation_backward_prop(dA_prev_temp,current_cache,activation="relu")[0]
        grads["dW" + str(l + 1)] = activation_backward_prop(dA_prev_temp,current_cache,activation="relu")[1]
        grads["db" + str(l + 1)] = activation_backward_prop(dA_prev_temp,current_cache,activation="relu")[2]

    return grads

# %%
def update_parameters(parameters, grads, learning_rate):

    #Update the parameters using the grads from the previous function
    
    L = len(parameters) // 2 # number of layers in the neural network

    # Update rule for each parameter. Use a for loop.
    for l in range(L):
        parameters["W" + str(l+1)] = parameters["W" + str(l+1)] - learning_rate*grads["dW" + str(l + 1)]
        parameters["b" + str(l+1)] = parameters["b" + str(l+1)] - learning_rate*grads["db" + str(l + 1)]
    return parameters

# %%
def predict(X, y, parameters):

    #This returns the predictions of the neural network
    
    m = X.shape[1]
    p = np.zeros((1,m))
    
    # Forward propagation
    values, caches = L_layer_forward_prop(X, parameters)

    for i in range(values.shape[1]):
        print("prediction: %f vs actual: %f \n" %(values[0][i], y[0][i]))


    list_comp = [round_num_to_nearest_base(values[0][i]) == round_num_to_nearest_base(y[0][i]) for i in range(values.shape[1])]
    

    print("Accuracy: "  + str(np.sum(list_comp)/m))

    fig, ax = plt.subplots(figsize=(8,8))
    xy_line = [0,1,2,3,4]
    xy_max = [0.2,1.2,2.2,3.2,4.2]
    xy_min = [-0.2,0.8,1.8,2.8,3.8] #Not actually negative but provides perspective
    ax.scatter(np.array(y),np.array(values))
    ax.plot(xy_line, 'r--')
    ax.plot(xy_max, 'b--')
    ax.plot(xy_min, 'b--')
    ax.set_ylabel('Perdicted value')
    ax.set_xlabel('Actual value')
    plt.show()
        
    return values

# %%
def parameter_regression_model(X, Y, layers_dims, learning_rate = 0.025, num_iterations = 3000, print_cost=True):

    costs = [] # keep track of cost
    
    parameters = initialise_parameters(layers_dims)
    
    # Loop (gradient descent)
    for i in range(0, num_iterations):


        AL, caches = L_layer_forward_prop(X, parameters)

        cost = cost_func(AL, Y)

        grads = L_layer_backward_prop(AL, Y, caches)

        parameters = update_parameters(parameters, grads, learning_rate)
    
                
        # Print the cost every 100 training example
        if print_cost and i % 100 == 0:
            print ("Cost after iteration %i: %f" %(i, cost))
        if print_cost and i % 100 == 0:
            costs.append(cost)

    # plot the cost
    plt.plot(np.squeeze(costs))
    plt.ylabel('cost')
    plt.xlabel('iterations (per hundreds)')
    plt.title("Learning rate =" + str(learning_rate))
    plt.show()
    
    return parameters

# %%
X_train = np.array(subparams_fid_int_train)
n_x = X_train.shape[0]
m_train = X_train.shape[1]
print(X_train.shape)
Y_train = np.array(comp_train).reshape((1,m_train))
print(Y_train.shape)
X_test = np.array(subparams_fid_int_test)
m_test = X_test.shape[1]
print(X_test.shape)
Y_test = np.array(comp_test).reshape((1,m_test))
print(Y_test.shape)
# Out:
# (9, 818)
# (1, 818)
# (9, 204)
# (1, 204)

# %%
#Checking
"""print(round_num_to_nearest_base(1.31))
print(round_num_to_nearest_base(1.77))
print(round_num_to_nearest_base(1.94))
print(round_num_to_nearest_base(100.15))"""
# Out:
# 'print(round_num_to_nearest_base(1.31))\nprint(round_num_to_nearest_base(1.77))\nprint(round_num_to_nearest_base(1.94))\nprint(round_num_to_nearest_base(100.15))'

# %%
layers_dims = [9,1]

best_params = parameter_regression_model(X_train, Y_train, layers_dims, num_iterations = 5000, print_cost = True)
# Out:
# Cost after iteration 0: 0.873120
# Cost after iteration 100: 0.540036
# Cost after iteration 200: 0.439079
# Cost after iteration 300: 0.367634
# Cost after iteration 400: 0.306810
# Cost after iteration 500: 0.254000
# Cost after iteration 600: 0.210601
# Cost after iteration 700: 0.174606
# Cost after iteration 800: 0.147024
# Cost after iteration 900: 0.121460
# Cost after iteration 1000: 0.101652
# Cost after iteration 1100: 0.086692
# Cost after iteration 1200: 0.075496
# Cost after iteration 1300: 0.067042
# Cost after iteration 1400: 0.060556
# Cost after iteration 1500: 0.055980
# Cost after iteration 1600: 0.052995
# Cost after iteration 1700: 0.051153
# Cost after iteration 1800: 0.050112
# Cost after iteration 1900: 0.049546
# Cost after iteration 2000: 0.049125
# Cost after iteration 2100: 0.048803
# Cost after iteration 2200: 0.048556
# Cost after iteration 2300: 0.048367
# Cost after iteration 2400: 0.048222
# Cost after iteration 2500: 0.048112
# Cost after iteration 2600: 0.048027
# Cost after iteration 2700: 0.047962
# Cost after iteration 2800: 0.047912
# Cost after iteration 2900: 0.047874
# Cost after iteration 3000: 0.047845
# Cost after iteration 3100: 0.047822
# Cost after iteration 3200: 0.047805
# Cost after iteration 3300: 0.047792
# Cost after iteration 3400: 0.047782
# Cost after iteration 3500: 0.047774
# Cost after iteration 3600: 0.047768
# Cost after iteration 3700: 0.047764
# Cost after iteration 3800: 0.047760
# Cost after iteration 3900: 0.047758
# Cost after iteration 4000: 0.047756
# Cost after iteration 4100: 0.047754
# Cost after iteration 4200: 0.047753
# Cost after iteration 4300: 0.047752
# Cost after iteration 4400: 0.047751
# Cost after iteration 4500: 0.047751
# Cost after iteration 4600: 0.047750
# Cost after iteration 4700: 0.047750
# Cost after iteration 4800: 0.047750
# Cost after iteration 4900: 0.047750

# %%
prediction_train = predict(X_train, Y_train, best_params)
# Out:
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.906220 vs actual: 1.000000
#
# prediction: 0.140927 vs actual: 0.000000
#
# prediction: 2.076265 vs actual: 3.000000
#
# prediction: 0.634746 vs actual: 1.000000
#
# prediction: 0.669283 vs actual: 2.000000
#
# prediction: 1.702703 vs actual: 2.000000
#
# prediction: 0.972769 vs actual: 1.000000
#
# prediction: 0.182495 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.923754 vs actual: 1.000000
#
# prediction: 1.514608 vs actual: 1.000000
#
# prediction: 2.052935 vs actual: 4.000000
#
# prediction: 1.457399 vs actual: 1.000000
#
# prediction: 0.450249 vs actual: 0.000000
#
# prediction: 0.409976 vs actual: 0.000000
#
# prediction: 1.387875 vs actual: 1.000000
#
# prediction: 1.305035 vs actual: 1.000000
#
# prediction: 0.481295 vs actual: 1.000000
#
# prediction: 0.553563 vs actual: 1.000000
#
# prediction: 0.789619 vs actual: 1.000000
#
# prediction: 0.664286 vs actual: 1.000000
#
# prediction: 2.093360 vs actual: 3.000000
#
# prediction: 0.681865 vs actual: 1.000000
#
# prediction: 1.426181 vs actual: 1.000000
#
# prediction: 1.459246 vs actual: 1.000000
#
# prediction: 0.521230 vs actual: 1.000000
#
# prediction: 0.330548 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.555542 vs actual: 1.000000
#
# prediction: 1.534123 vs actual: 1.000000
#
# prediction: 0.466450 vs actual: 1.000000
#
# prediction: 1.390423 vs actual: 1.000000
#
# prediction: 0.150059 vs actual: 0.000000
#
# prediction: 1.384534 vs actual: 2.000000
#
# prediction: 1.185199 vs actual: 1.000000
#
# prediction: 0.495166 vs actual: 1.000000
#
# prediction: 0.415962 vs actual: 0.000000
#
# prediction: 1.703775 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.424409 vs actual: 0.000000
#
# prediction: 0.187796 vs actual: 0.000000
#
# prediction: 1.211981 vs actual: 2.000000
#
# prediction: 1.074327 vs actual: 1.000000
#
# prediction: 1.343939 vs actual: 1.000000
#
# prediction: 1.024283 vs actual: 1.000000
#
# prediction: 1.481846 vs actual: 1.000000
#
# prediction: 1.152235 vs actual: 1.000000
#
# prediction: 2.387911 vs actual: 3.000000
#
# prediction: 0.127153 vs actual: 0.000000
#
# prediction: 0.656097 vs actual: 1.000000
#
# prediction: 1.218327 vs actual: 1.000000
#
# prediction: 0.909392 vs actual: 1.000000
#
# prediction: 0.456210 vs actual: 0.000000
#
# prediction: 0.240893 vs actual: 0.000000
#
# prediction: 0.056198 vs actual: 0.000000
#
# prediction: 0.867501 vs actual: 1.000000
#
# prediction: 1.103902 vs actual: 1.000000
#
# prediction: 0.972166 vs actual: 1.000000
#
# prediction: 0.364355 vs actual: 0.000000
#
# prediction: 2.264766 vs actual: 2.000000
#
# prediction: 0.837927 vs actual: 1.000000
#
# prediction: 1.955100 vs actual: 2.000000
#
# prediction: 1.220681 vs actual: 1.000000
#
# prediction: 3.154980 vs actual: 4.000000
#
# prediction: 3.163040 vs actual: 3.000000
#
# prediction: 2.170065 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.141586 vs actual: 0.000000
#
# prediction: 0.570521 vs actual: 1.000000
#
# prediction: 0.114300 vs actual: 0.000000
#
# prediction: 0.281192 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.565761 vs actual: 2.000000
#
# prediction: 0.631798 vs actual: 1.000000
#
# prediction: 0.518058 vs actual: 1.000000
#
# prediction: 0.296262 vs actual: 0.000000
#
# prediction: 0.406830 vs actual: 0.000000
#
# prediction: 0.814728 vs actual: 1.000000
#
# prediction: 0.558864 vs actual: 1.000000
#
# prediction: 0.684037 vs actual: 1.000000
#
# prediction: 1.194441 vs actual: 1.000000
#
# prediction: 1.352412 vs actual: 1.000000
#
# prediction: 1.139661 vs actual: 1.000000
#
# prediction: 1.309652 vs actual: 1.000000
#
# prediction: 1.126369 vs actual: 1.000000
#
# prediction: 0.304709 vs actual: 0.000000
#
# prediction: 1.183329 vs actual: 1.000000
#
# prediction: 2.100432 vs actual: 2.000000
#
# prediction: 0.249366 vs actual: 0.000000
#
# prediction: 0.529703 vs actual: 1.000000
#
# prediction: 0.740800 vs actual: 1.000000
#
# prediction: 3.226621 vs actual: 3.000000
#
# prediction: 1.590060 vs actual: 2.000000
#
# prediction: 0.555516 vs actual: 1.000000
#
# prediction: 1.828188 vs actual: 2.000000
#
# prediction: 2.025316 vs actual: 2.000000
#
# prediction: 1.206338 vs actual: 1.000000
#
# prediction: 0.833189 vs actual: 1.000000
#
# prediction: 1.562337 vs actual: 2.000000
#
# prediction: 1.463666 vs actual: 1.000000
#
# prediction: 0.891767 vs actual: 1.000000
#
# prediction: 2.153739 vs actual: 2.000000
#
# prediction: 2.060085 vs actual: 2.000000
#
# prediction: 0.385774 vs actual: 0.000000
#
# prediction: 0.435180 vs actual: 0.000000
#
# prediction: 1.457455 vs actual: 1.000000
#
# prediction: 0.518058 vs actual: 1.000000
#
# prediction: 0.419765 vs actual: 0.000000
#
# prediction: 1.176759 vs actual: 1.000000
#
# prediction: 2.020018 vs actual: 2.000000
#
# prediction: 1.765049 vs actual: 2.000000
#
# prediction: 2.163879 vs actual: 2.000000
#
# prediction: 1.025947 vs actual: 1.000000
#
# prediction: 1.933156 vs actual: 2.000000
#
# prediction: 1.940764 vs actual: 2.000000
#
# prediction: 1.630785 vs actual: 2.000000
#
# prediction: 0.753480 vs actual: 1.000000
#
# prediction: 1.046977 vs actual: 1.000000
#
# prediction: 0.859350 vs actual: 1.000000
#
# prediction: 1.809145 vs actual: 2.000000
#
# prediction: 0.859350 vs actual: 1.000000
#
# prediction: 2.443148 vs actual: 2.000000
#
# prediction: 1.953949 vs actual: 2.000000
#
# prediction: 0.719770 vs actual: 1.000000
#
# prediction: 2.472734 vs actual: 2.000000
#
# prediction: 2.085268 vs actual: 2.000000
#
# prediction: 2.117423 vs actual: 2.000000
#
# prediction: 1.167626 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.068251 vs actual: 2.000000
#
# prediction: 0.357448 vs actual: 0.000000
#
# prediction: 0.398383 vs actual: 0.000000
#
# prediction: 1.880105 vs actual: 2.000000
#
# prediction: 0.541672 vs actual: 1.000000
#
# prediction: 0.141586 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.030358 vs actual: 0.000000
#
# prediction: 0.359147 vs actual: 0.000000
#
# prediction: 1.472113 vs actual: 1.000000
#
# prediction: 1.546937 vs actual: 2.000000
#
# prediction: 1.985767 vs actual: 2.000000
#
# prediction: 0.190968 vs actual: 0.000000
#
# prediction: 2.156060 vs actual: 2.000000
#
# prediction: 0.384234 vs actual: 0.000000
#
# prediction: 0.885144 vs actual: 1.000000
#
# prediction: 0.421238 vs actual: 0.000000
#
# prediction: 0.360594 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.701800 vs actual: 3.000000
#
# prediction: 0.021885 vs actual: 0.000000
#
# prediction: 1.349240 vs actual: 1.000000
#
# prediction: 1.108825 vs actual: 1.000000
#
# prediction: 0.749933 vs actual: 1.000000
#
# prediction: 0.685964 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.056198 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.446060 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.323257 vs actual: 2.000000
#
# prediction: 0.130913 vs actual: 0.000000
#
# prediction: 0.816707 vs actual: 1.000000
#
# prediction: 0.757550 vs actual: 1.000000
#
# prediction: 0.373581 vs actual: 0.000000
#
# prediction: 0.394611 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.150059 vs actual: 0.000000
#
# prediction: 0.604460 vs actual: 1.000000
#
# prediction: 1.786278 vs actual: 2.000000
#
# prediction: 0.771030 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.349921 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.322532 vs actual: 0.000000
#
# prediction: 1.781331 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.846483 vs actual: 2.000000
#
# prediction: 0.690384 vs actual: 1.000000
#
# prediction: 0.590980 vs actual: 1.000000
#
# prediction: 0.667380 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.818119 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.947614 vs actual: 1.000000
#
# prediction: 0.166767 vs actual: 0.000000
#
# prediction: 1.136244 vs actual: 1.000000
#
# prediction: 0.964347 vs actual: 1.000000
#
# prediction: 2.553690 vs actual: 3.000000
#
# prediction: 0.353016 vs actual: 0.000000
#
# prediction: 0.426047 vs actual: 0.000000
#
# prediction: 1.823460 vs actual: 2.000000
#
# prediction: 2.519884 vs actual: 2.000000
#
# prediction: 0.056198 vs actual: 0.000000
#
# prediction: 0.766051 vs actual: 1.000000
#
# prediction: 0.196929 vs actual: 0.000000
#
# prediction: 0.077228 vs actual: 0.000000
#
# prediction: 0.276454 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.815635 vs actual: 1.000000
#
# prediction: 0.281166 vs actual: 0.000000
#
# prediction: 0.286467 vs actual: 0.000000
#
# prediction: 0.114300 vs actual: 0.000000
#
# prediction: 0.252181 vs actual: 0.000000
#
# prediction: 0.211964 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.340767 vs actual: 1.000000
#
# prediction: 1.600380 vs actual: 2.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.135626 vs actual: 0.000000
#
# prediction: 1.553107 vs actual: 2.000000
#
# prediction: 1.913891 vs actual: 2.000000
#
# prediction: 0.240893 vs actual: 0.000000
#
# prediction: 0.621785 vs actual: 1.000000
#
# prediction: 2.325374 vs actual: 2.000000
#
# prediction: 0.119575 vs actual: 0.000000
#
# prediction: 0.556765 vs actual: 1.000000
#
# prediction: 1.673541 vs actual: 2.000000
#
# prediction: 3.059728 vs actual: 3.000000
#
# prediction: 1.251550 vs actual: 1.000000
#
# prediction: 0.406804 vs actual: 0.000000
#
# prediction: 1.797730 vs actual: 2.000000
#
# prediction: 0.944442 vs actual: 1.000000
#
# prediction: 0.840568 vs actual: 1.000000
#
# prediction: 1.400413 vs actual: 1.000000
#
# prediction: 0.985351 vs actual: 1.000000
#
# prediction: 1.491579 vs actual: 2.000000
#
# prediction: 0.141586 vs actual: 0.000000
#
# prediction: 1.747310 vs actual: 2.000000
#
# prediction: 3.139156 vs actual: 3.000000
#
# prediction: 0.612626 vs actual: 1.000000
#
# prediction: 0.787204 vs actual: 1.000000
#
# prediction: 1.246838 vs actual: 1.000000
#
# prediction: 0.518058 vs actual: 1.000000
#
# prediction: 0.260628 vs actual: 0.000000
#
# prediction: 1.640352 vs actual: 2.000000
#
# prediction: 2.293153 vs actual: 2.000000
#
# prediction: 2.401754 vs actual: 2.000000
#
# prediction: 2.849486 vs actual: 3.000000
#
# prediction: 0.536396 vs actual: 1.000000
#
# prediction: 0.529452 vs actual: 1.000000
#
# prediction: 1.367543 vs actual: 1.000000
#
# prediction: 1.570550 vs actual: 2.000000
#
# prediction: 1.405284 vs actual: 1.000000
#
# prediction: 0.536396 vs actual: 1.000000
#
# prediction: 1.476545 vs actual: 1.000000
#
# prediction: 0.567327 vs actual: 1.000000
#
# prediction: 1.476545 vs actual: 1.000000
#
# prediction: 1.544224 vs actual: 1.000000
#
# prediction: 1.786017 vs actual: 2.000000
#
# prediction: 1.476545 vs actual: 1.000000
#
# prediction: 2.722493 vs actual: 3.000000
#
# prediction: 2.258945 vs actual: 2.000000
#
# prediction: 2.424002 vs actual: 2.000000
#
# prediction: 1.368713 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.453008 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.339834 vs actual: 2.000000
#
# prediction: 0.223302 vs actual: 0.000000
#
# prediction: 0.175899 vs actual: 0.000000
#
# prediction: 1.303056 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.508325 vs actual: 1.000000
#
# prediction: 0.119575 vs actual: 0.000000
#
# prediction: 0.465318 vs actual: 0.000000
#
# prediction: 1.357150 vs actual: 1.000000
#
# prediction: 2.168138 vs actual: 2.000000
#
# prediction: 2.289134 vs actual: 2.000000
#
# prediction: 0.673771 vs actual: 1.000000
#
# prediction: 0.190968 vs actual: 0.000000
#
# prediction: 1.652863 vs actual: 2.000000
#
# prediction: 0.889539 vs actual: 1.000000
#
# prediction: 0.837518 vs actual: 1.000000
#
# prediction: 0.354409 vs actual: 0.000000
#
# prediction: 0.823493 vs actual: 1.000000
#
# prediction: 0.021911 vs actual: 0.000000
#
# prediction: 2.330952 vs actual: 2.000000
#
# prediction: 0.056198 vs actual: 0.000000
#
# prediction: 1.322587 vs actual: 1.000000
#
# prediction: 0.289317 vs actual: 0.000000
#
# prediction: 0.555516 vs actual: 1.000000
#
# prediction: 0.364448 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.512169 vs actual: 1.000000
#
# prediction: 0.853779 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.161402 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.653206 vs actual: 1.000000
#
# prediction: 1.178723 vs actual: 1.000000
#
# prediction: 0.296236 vs actual: 0.000000
#
# prediction: 0.169616 vs actual: 0.000000
#
# prediction: 1.066723 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.056198 vs actual: 0.000000
#
# prediction: 0.206662 vs actual: 0.000000
#
# prediction: 1.261230 vs actual: 1.000000
#
# prediction: 0.604486 vs actual: 1.000000
#
# prediction: 1.194591 vs actual: 1.000000
#
# prediction: 0.250614 vs actual: 0.000000
#
# prediction: 1.180183 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.460318 vs actual: 1.000000
#
# prediction: 0.252181 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.845613 vs actual: 1.000000
#
# prediction: 0.883230 vs actual: 1.000000
#
# prediction: 1.155487 vs actual: 1.000000
#
# prediction: 0.021885 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.901457 vs actual: 2.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.809068 vs actual: 2.000000
#
# prediction: 1.167278 vs actual: 1.000000
#
# prediction: 2.329408 vs actual: 2.000000
#
# prediction: 1.188630 vs actual: 1.000000
#
# prediction: 0.981995 vs actual: 1.000000
#
# prediction: 2.933360 vs actual: 3.000000
#
# prediction: 2.955934 vs actual: 3.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.182495 vs actual: 0.000000
#
# prediction: 0.397097 vs actual: 0.000000
#
# prediction: 0.401529 vs actual: 0.000000
#
# prediction: 0.228014 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.666085 vs actual: 1.000000
#
# prediction: 0.325423 vs actual: 0.000000
#
# prediction: 0.357448 vs actual: 0.000000
#
# prediction: 0.373581 vs actual: 0.000000
#
# prediction: 0.508351 vs actual: 1.000000
#
# prediction: 0.224868 vs actual: 0.000000
#
# prediction: 0.224868 vs actual: 0.000000
#
# prediction: 0.412765 vs actual: 0.000000
#
# prediction: 1.632112 vs actual: 2.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 2.438728 vs actual: 2.000000
#
# prediction: 1.551556 vs actual: 1.000000
#
# prediction: 1.790248 vs actual: 2.000000
#
# prediction: 0.306347 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.069589 vs actual: 1.000000
#
# prediction: 0.144099 vs actual: 0.000000
#
# prediction: 0.583456 vs actual: 1.000000
#
# prediction: 1.590731 vs actual: 2.000000
#
# prediction: 0.844621 vs actual: 1.000000
#
# prediction: 1.787031 vs actual: 2.000000
#
# prediction: 1.495033 vs actual: 2.000000
#
# prediction: 1.626447 vs actual: 2.000000
#
# prediction: 2.088413 vs actual: 2.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.600048 vs actual: 2.000000
#
# prediction: 1.547862 vs actual: 2.000000
#
# prediction: 1.319737 vs actual: 1.000000
#
# prediction: 0.296236 vs actual: 0.000000
#
# prediction: 2.100117 vs actual: 2.000000
#
# prediction: 1.319763 vs actual: 1.000000
#
# prediction: 0.499192 vs actual: 1.000000
#
# prediction: 0.587554 vs actual: 1.000000
#
# prediction: 1.412258 vs actual: 1.000000
#
# prediction: 0.518058 vs actual: 1.000000
#
# prediction: 0.606056 vs actual: 1.000000
#
# prediction: 1.282267 vs actual: 1.000000
#
# prediction: 2.393211 vs actual: 2.000000
#
# prediction: 1.570952 vs actual: 2.000000
#
# prediction: 2.331613 vs actual: 2.000000
#
# prediction: 1.322909 vs actual: 1.000000
#
# prediction: 0.253854 vs actual: 0.000000
#
# prediction: 1.863354 vs actual: 2.000000
#
# prediction: 1.676758 vs actual: 2.000000
#
# prediction: 0.297484 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.784657 vs actual: 1.000000
#
# prediction: 0.728996 vs actual: 1.000000
#
# prediction: 0.804658 vs actual: 1.000000
#
# prediction: 1.750444 vs actual: 2.000000
#
# prediction: 1.912692 vs actual: 2.000000
#
# prediction: 0.784657 vs actual: 1.000000
#
# prediction: 2.273216 vs actual: 2.000000
#
# prediction: 2.177347 vs actual: 2.000000
#
# prediction: 2.620439 vs actual: 3.000000
#
# prediction: 0.694695 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.114371 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.703775 vs actual: 2.000000
#
# prediction: 0.499878 vs actual: 1.000000
#
# prediction: 1.563827 vs actual: 2.000000
#
# prediction: 1.301557 vs actual: 1.000000
#
# prediction: 0.224842 vs actual: 0.000000
#
# prediction: 0.141586 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.406804 vs actual: 0.000000
#
# prediction: 0.548953 vs actual: 1.000000
#
# prediction: 1.323722 vs actual: 1.000000
#
# prediction: 2.032253 vs actual: 2.000000
#
# prediction: 0.760357 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.176824 vs actual: 1.000000
#
# prediction: 2.148377 vs actual: 2.000000
#
# prediction: 0.309518 vs actual: 0.000000
#
# prediction: 0.268288 vs actual: 0.000000
#
# prediction: 0.351461 vs actual: 0.000000
#
# prediction: 0.144099 vs actual: 0.000000
#
# prediction: 2.594705 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.752744 vs actual: 2.000000
#
# prediction: 0.672707 vs actual: 1.000000
#
# prediction: 0.190968 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.343014 vs actual: 0.000000
#
# prediction: 0.512169 vs actual: 1.000000
#
# prediction: 2.024904 vs actual: 2.000000
#
# prediction: 0.030358 vs actual: 0.000000
#
# prediction: 0.847793 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.713814 vs actual: 2.000000
#
# prediction: 0.968137 vs actual: 1.000000
#
# prediction: 0.280185 vs actual: 0.000000
#
# prediction: 0.262046 vs actual: 0.000000
#
# prediction: 1.444494 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.073677 vs actual: 1.000000
#
# prediction: 0.944923 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.030358 vs actual: 0.000000
#
# prediction: 2.012025 vs actual: 2.000000
#
# prediction: 0.027187 vs actual: 0.000000
#
# prediction: 2.049603 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.401503 vs actual: 0.000000
#
# prediction: 0.916014 vs actual: 1.000000
#
# prediction: 1.244928 vs actual: 1.000000
#
# prediction: 0.622640 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.863767 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.339268 vs actual: 0.000000
#
# prediction: 0.030358 vs actual: 0.000000
#
# prediction: 1.381117 vs actual: 1.000000
#
# prediction: 1.052316 vs actual: 1.000000
#
# prediction: 2.999673 vs actual: 3.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.817715 vs actual: 2.000000
#
# prediction: 3.343185 vs actual: 3.000000
#
# prediction: 2.456615 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.360594 vs actual: 0.000000
#
# prediction: 0.030358 vs actual: 0.000000
#
# prediction: 0.242167 vs actual: 0.000000
#
# prediction: 0.135652 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.628785 vs actual: 1.000000
#
# prediction: 0.246220 vs actual: 0.000000
#
# prediction: 0.552345 vs actual: 1.000000
#
# prediction: 0.495462 vs actual: 1.000000
#
# prediction: 0.484149 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.647905 vs actual: 1.000000
#
# prediction: 1.074890 vs actual: 1.000000
#
# prediction: 0.261287 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.760679 vs actual: 1.000000
#
# prediction: 1.833905 vs actual: 2.000000
#
# prediction: 0.196929 vs actual: 0.000000
#
# prediction: 0.788733 vs actual: 1.000000
#
# prediction: 2.252604 vs actual: 2.000000
#
# prediction: 2.706456 vs actual: 3.000000
#
# prediction: 0.144099 vs actual: 0.000000
#
# prediction: 0.190968 vs actual: 0.000000
#
# prediction: 2.147185 vs actual: 2.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 2.024930 vs actual: 2.000000
#
# prediction: 0.765121 vs actual: 1.000000
#
# prediction: 1.645567 vs actual: 2.000000
#
# prediction: 1.613456 vs actual: 2.000000
#
# prediction: 1.737675 vs actual: 2.000000
#
# prediction: 2.114120 vs actual: 2.000000
#
# prediction: 1.483545 vs actual: 1.000000
#
# prediction: 1.283910 vs actual: 1.000000
#
# prediction: 0.899670 vs actual: 1.000000
#
# prediction: 0.977200 vs actual: 1.000000
#
# prediction: 1.124931 vs actual: 1.000000
#
# prediction: 1.007741 vs actual: 1.000000
#
# prediction: 0.380499 vs actual: 0.000000
#
# prediction: 1.790070 vs actual: 2.000000
#
# prediction: 0.518058 vs actual: 1.000000
#
# prediction: 0.368842 vs actual: 0.000000
#
# prediction: 1.673193 vs actual: 2.000000
#
# prediction: 1.126085 vs actual: 1.000000
#
# prediction: 1.713304 vs actual: 2.000000
#
# prediction: 2.002867 vs actual: 2.000000
#
# prediction: 1.669488 vs actual: 2.000000
#
# prediction: 2.079581 vs actual: 2.000000
#
# prediction: 1.490065 vs actual: 2.000000
#
# prediction: 2.213415 vs actual: 2.000000
#
# prediction: 0.868187 vs actual: 1.000000
#
# prediction: 1.403611 vs actual: 1.000000
#
# prediction: 1.446060 vs actual: 1.000000
#
# prediction: 0.322101 vs actual: 0.000000
#
# prediction: 1.446060 vs actual: 1.000000
#
# prediction: 1.556178 vs actual: 2.000000
#
# prediction: 1.540300 vs actual: 2.000000
#
# prediction: 1.480347 vs actual: 1.000000
#
# prediction: 2.228827 vs actual: 2.000000
#
# prediction: 1.587544 vs actual: 2.000000
#
# prediction: 2.489991 vs actual: 2.000000
#
# prediction: 1.203723 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.875310 vs actual: 2.000000
#
# prediction: 0.127153 vs actual: 0.000000
#
# prediction: 2.856771 vs actual: 3.000000
#
# prediction: 0.526531 vs actual: 1.000000
#
# prediction: 1.430894 vs actual: 1.000000
#
# prediction: 1.568933 vs actual: 2.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.021885 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.928242 vs actual: 1.000000
#
# prediction: 1.176661 vs actual: 1.000000
#
# prediction: 1.843729 vs actual: 2.000000
#
# prediction: 1.493107 vs actual: 1.000000
#
# prediction: 0.030358 vs actual: 0.000000
#
# prediction: 1.597532 vs actual: 2.000000
#
# prediction: 1.481794 vs actual: 1.000000
#
# prediction: 1.615439 vs actual: 2.000000
#
# prediction: 0.724187 vs actual: 1.000000
#
# prediction: 0.346160 vs actual: 0.000000
#
# prediction: 0.367620 vs actual: 0.000000
#
# prediction: 1.644279 vs actual: 2.000000
#
# prediction: 0.727052 vs actual: 1.000000
#
# prediction: 1.619447 vs actual: 2.000000
#
# prediction: 1.117957 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.119575 vs actual: 0.000000
#
# prediction: 0.606030 vs actual: 1.000000
#
# prediction: 0.922431 vs actual: 1.000000
#
# prediction: 0.130913 vs actual: 0.000000
#
# prediction: 0.910958 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.049050 vs actual: 1.000000
#
# prediction: 0.757550 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.056198 vs actual: 0.000000
#
# prediction: 0.536371 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.119575 vs actual: 0.000000
#
# prediction: 3.677782 vs actual: 4.000000
#
# prediction: 0.735593 vs actual: 1.000000
#
# prediction: 1.327888 vs actual: 1.000000
#
# prediction: 1.744133 vs actual: 2.000000
#
# prediction: 1.183355 vs actual: 1.000000
#
# prediction: 0.355882 vs actual: 0.000000
#
# prediction: 1.434696 vs actual: 2.000000
#
# prediction: 0.724187 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.866684 vs actual: 1.000000
#
# prediction: 0.782360 vs actual: 1.000000
#
# prediction: 0.852334 vs actual: 1.000000
#
# prediction: 1.417662 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.166767 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.265984 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.172635 vs actual: 2.000000
#
# prediction: 1.632408 vs actual: 2.000000
#
# prediction: 2.722467 vs actual: 3.000000
#
# prediction: 0.859054 vs actual: 1.000000
#
# prediction: 0.975338 vs actual: 1.000000
#
# prediction: 3.231798 vs actual: 3.000000
#
# prediction: 2.485038 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.494480 vs actual: 1.000000
#
# prediction: 0.625812 vs actual: 1.000000
#
# prediction: 0.177783 vs actual: 0.000000
#
# prediction: 0.017173 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.755301 vs actual: 1.000000
#
# prediction: 0.644759 vs actual: 1.000000
#
# prediction: 0.252181 vs actual: 0.000000
#
# prediction: 0.396791 vs actual: 0.000000
#
# prediction: 0.761671 vs actual: 1.000000
#
# prediction: 0.803712 vs actual: 1.000000
#
# prediction: 0.480732 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.674832 vs actual: 2.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.729538 vs actual: 1.000000
#
# prediction: 2.117292 vs actual: 2.000000
#
# prediction: 0.565168 vs actual: 1.000000
#
# prediction: 0.342696 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 2.927445 vs actual: 3.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.296236 vs actual: 0.000000
#
# prediction: 1.434628 vs actual: 1.000000
#
# prediction: 2.843867 vs actual: 3.000000
#
# prediction: 2.172635 vs actual: 2.000000
#
# prediction: 0.621785 vs actual: 1.000000
#
# prediction: 1.547581 vs actual: 2.000000
#
# prediction: 1.074890 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.299858 vs actual: 1.000000
#
# prediction: 2.119457 vs actual: 2.000000
#
# prediction: 1.078062 vs actual: 1.000000
#
# prediction: 0.415936 vs actual: 0.000000
#
# prediction: 0.993518 vs actual: 1.000000
#
# prediction: 2.631044 vs actual: 3.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.791714 vs actual: 1.000000
#
# prediction: 1.701822 vs actual: 2.000000
#
# prediction: 0.518058 vs actual: 1.000000
#
# prediction: 0.281166 vs actual: 0.000000
#
# prediction: 1.116235 vs actual: 1.000000
#
# prediction: 2.123315 vs actual: 2.000000
#
# prediction: 1.416233 vs actual: 1.000000
#
# prediction: 1.505706 vs actual: 2.000000
#
# prediction: 0.816681 vs actual: 1.000000
#
# prediction: 3.546168 vs actual: 3.000000
#
# prediction: 0.944821 vs actual: 1.000000
#
# prediction: 1.358569 vs actual: 1.000000
#
# prediction: 0.850888 vs actual: 1.000000
#
# prediction: 0.930422 vs actual: 1.000000
#
# prediction: 1.491711 vs actual: 1.000000
#
# prediction: 2.171797 vs actual: 2.000000
#
# prediction: 1.483545 vs actual: 1.000000
#
# prediction: 0.993892 vs actual: 1.000000
#
# prediction: 1.819107 vs actual: 2.000000
#
# prediction: 1.483545 vs actual: 1.000000
#
# prediction: 2.344548 vs actual: 2.000000
#
# prediction: 2.297637 vs actual: 2.000000
#
# prediction: 2.328416 vs actual: 2.000000
#
# prediction: 0.854338 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.272546 vs actual: 1.000000
#
# prediction: 0.330110 vs actual: 0.000000
#
# prediction: 1.809068 vs actual: 2.000000
#
# prediction: 0.587850 vs actual: 1.000000
#
# prediction: 2.122593 vs actual: 2.000000
#
# prediction: 0.351461 vs actual: 0.000000
#
# prediction: 0.122747 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.950400 vs actual: 2.000000
#
# prediction: 2.655812 vs actual: 3.000000
#
# prediction: 2.100045 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.684797 vs actual: 3.000000
#
# prediction: 0.132480 vs actual: 0.000000
#
# prediction: 1.606542 vs actual: 2.000000
#
# prediction: 2.420804 vs actual: 2.000000
#
# prediction: 0.296236 vs actual: 0.000000
#
# prediction: 0.744066 vs actual: 1.000000
#
# prediction: 1.439438 vs actual: 1.000000
#
# prediction: 1.556066 vs actual: 2.000000
#
# prediction: 0.955163 vs actual: 1.000000
#
# prediction: 2.852249 vs actual: 3.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.881722 vs actual: 3.000000
#
# prediction: 0.009007 vs actual: 0.000000
#
# prediction: 0.182495 vs actual: 0.000000
#
# prediction: 0.579966 vs actual: 1.000000
#
# prediction: 1.018003 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.262212 vs actual: 1.000000
#
# prediction: 0.965888 vs actual: 1.000000
#
# prediction: 1.709996 vs actual: 2.000000
#
# prediction: 1.176411 vs actual: 1.000000
#
# prediction: 1.046538 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.782748 vs actual: 2.000000
#
# prediction: 0.394933 vs actual: 0.000000
#
# prediction: 1.118309 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.396791 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.694642 vs actual: 2.000000
#
# prediction: 0.135626 vs actual: 0.000000
#
# prediction: 1.128103 vs actual: 1.000000
#
# prediction: 2.065681 vs actual: 2.000000
#
# prediction: 2.827760 vs actual: 3.000000
#
# prediction: 1.074890 vs actual: 1.000000
#
# prediction: 0.190968 vs actual: 0.000000
#
# prediction: 0.635601 vs actual: 1.000000
#
# prediction: 1.379312 vs actual: 1.000000
#
# prediction: 0.466476 vs actual: 1.000000
#
# prediction: 1.238672 vs actual: 1.000000
#
# prediction: 2.310236 vs actual: 2.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 2.813633 vs actual: 3.000000
#
# prediction: 3.173469 vs actual: 3.000000
#
# prediction: 2.480859 vs actual: 2.000000
#
# prediction: 3.539901 vs actual: 3.000000
#
# prediction: 1.315991 vs actual: 1.000000
#
# prediction: 0.132480 vs actual: 0.000000
#
# prediction: 2.114146 vs actual: 2.000000
#
# prediction: 0.518058 vs actual: 1.000000
#
# prediction: 0.412791 vs actual: 0.000000
#
# prediction: 0.334556 vs actual: 0.000000
#
# prediction: 2.202175 vs actual: 2.000000
#
# prediction: 2.049002 vs actual: 2.000000
#
# prediction: 1.553204 vs actual: 2.000000
#
# prediction: 1.449232 vs actual: 1.000000
#
# prediction: 1.365066 vs actual: 1.000000
#
# prediction: 1.760259 vs actual: 2.000000
#
# prediction: 1.628338 vs actual: 2.000000
#
# prediction: 2.151189 vs actual: 2.000000
#
# prediction: 1.449232 vs actual: 1.000000
#
# prediction: 2.107279 vs actual: 2.000000
#
# prediction: 2.107279 vs actual: 2.000000
#
# prediction: 1.744174 vs actual: 2.000000
#
# prediction: 1.660356 vs actual: 2.000000
#
# prediction: 2.002012 vs actual: 2.000000
#
# prediction: 2.206922 vs actual: 2.000000
#
# prediction: 2.025236 vs actual: 2.000000
#
# prediction: 0.633242 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.673841 vs actual: 3.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.516644 vs actual: 2.000000
#
# prediction: 0.414464 vs actual: 0.000000
#
# prediction: 1.521154 vs actual: 2.000000
#
# prediction: 0.246194 vs actual: 0.000000
#
# prediction: 0.495462 vs actual: 1.000000
#
# prediction: 0.512097 vs actual: 1.000000
#
# prediction: 1.790096 vs actual: 2.000000
#
# prediction: 2.324987 vs actual: 2.000000
#
# prediction: 1.187995 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.375085 vs actual: 2.000000
#
# prediction: 0.141612 vs actual: 0.000000
#
# prediction: 2.044767 vs actual: 2.000000
#
# prediction: 2.012025 vs actual: 2.000000
#
# prediction: 0.871933 vs actual: 1.000000
#
# prediction: 0.910958 vs actual: 1.000000
#
# prediction: 0.660810 vs actual: 1.000000
#
# prediction: 0.391735 vs actual: 0.000000
#
# prediction: 1.313069 vs actual: 1.000000
#
# prediction: 0.122466 vs actual: 0.000000
#
# prediction: 0.994638 vs actual: 1.000000
#
# prediction: 0.036319 vs actual: 0.000000
#
# prediction: 0.666085 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.285450 vs actual: 1.000000
#
# prediction: 0.182495 vs actual: 0.000000
#
# prediction: 1.814369 vs actual: 2.000000
#
# prediction: 0.747238 vs actual: 1.000000
#
# prediction: 0.119575 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.297811 vs actual: 1.000000
#
# prediction: 0.333870 vs actual: 0.000000
#
# prediction: 1.489480 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.084022 vs actual: 1.000000
#
# prediction: 0.546410 vs actual: 1.000000
#
# prediction: 0.380525 vs actual: 0.000000
#
# prediction: 1.622738 vs actual: 2.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 2.847639 vs actual: 3.000000
#
# prediction: 1.791769 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.388624 vs actual: 0.000000
#
# prediction: 1.589108 vs actual: 2.000000
#
# prediction: 0.837646 vs actual: 1.000000
#
# prediction: 1.444494 vs actual: 1.000000
#
# prediction: 0.656578 vs actual: 1.000000
#
# prediction: 1.167278 vs actual: 1.000000
#
# prediction: 3.230393 vs actual: 3.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.440678 vs actual: 1.000000
#
# prediction: 2.840695 vs actual: 3.000000
#
# prediction: 0.518058 vs actual: 1.000000
#
# prediction: 0.599773 vs actual: 1.000000
#
# prediction: 1.390021 vs actual: 1.000000
#
# prediction: 1.690457 vs actual: 2.000000
#
# prediction: 1.639887 vs actual: 2.000000
#
# prediction: 0.922125 vs actual: 1.000000
#
# prediction: 1.124931 vs actual: 1.000000
#
# prediction: 3.359638 vs actual: 3.000000
#
# prediction: 1.940764 vs actual: 2.000000
#
# prediction: 1.148387 vs actual: 2.000000
#
# prediction: 1.167938 vs actual: 2.000000
#
# prediction: 0.904676 vs actual: 2.000000
#
# prediction: 2.227861 vs actual: 2.000000
#
# prediction: 2.227861 vs actual: 2.000000
#
# prediction: 1.118880 vs actual: 1.000000
#
# prediction: 1.538745 vs actual: 2.000000
#
# prediction: 2.223148 vs actual: 2.000000
#
# prediction: 2.131404 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.263324 vs actual: 2.000000
#
# prediction: 0.150059 vs actual: 0.000000
#
# prediction: 1.794313 vs actual: 2.000000
#
# prediction: 1.479466 vs actual: 3.000000
#
# prediction: 0.536371 vs actual: 1.000000
#
# prediction: 0.169938 vs actual: 0.000000
#
# Accuracy: 0.2628361858190709

# %%
prediction_test = predict(X_test, Y_test, best_params)
# Out:
# prediction: 0.422937 vs actual: 0.000000
#
# prediction: 1.103902 vs actual: 1.000000
#
# prediction: 1.880892 vs actual: 2.000000
#
# prediction: 2.282643 vs actual: 2.000000
#
# prediction: 1.271661 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 2.853906 vs actual: 3.000000
#
# prediction: 2.620465 vs actual: 3.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.025921 vs actual: 1.000000
#
# prediction: 1.565761 vs actual: 2.000000
#
# prediction: 0.236207 vs actual: 0.000000
#
# prediction: 1.662862 vs actual: 3.000000
#
# prediction: 0.150059 vs actual: 0.000000
#
# prediction: 0.395422 vs actual: 0.000000
#
# prediction: 0.132454 vs actual: 0.000000
#
# prediction: 1.188630 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.612441 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.638798 vs actual: 1.000000
#
# prediction: 0.588409 vs actual: 1.000000
#
# prediction: 1.791795 vs actual: 2.000000
#
# prediction: 0.725579 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.743110 vs actual: 2.000000
#
# prediction: 0.449836 vs actual: 1.000000
#
# prediction: 0.788958 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.176437 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.796163 vs actual: 2.000000
#
# prediction: 2.834734 vs actual: 3.000000
#
# prediction: 0.135626 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.499192 vs actual: 1.000000
#
# prediction: 0.719448 vs actual: 1.000000
#
# prediction: 0.505153 vs actual: 1.000000
#
# prediction: 2.060689 vs actual: 2.000000
#
# prediction: 1.272572 vs actual: 1.000000
#
# prediction: 0.490745 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.998323 vs actual: 1.000000
#
# prediction: 2.498480 vs actual: 2.000000
#
# prediction: 0.387022 vs actual: 0.000000
#
# prediction: 0.302196 vs actual: 0.000000
#
# prediction: 1.397118 vs actual: 1.000000
#
# prediction: 1.550915 vs actual: 2.000000
#
# prediction: 1.708354 vs actual: 2.000000
#
# prediction: 1.150571 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 2.564748 vs actual: 3.000000
#
# prediction: 2.215062 vs actual: 2.000000
#
# prediction: 1.576830 vs actual: 2.000000
#
# prediction: 0.810308 vs actual: 1.000000
#
# prediction: 0.745314 vs actual: 1.000000
#
# prediction: 1.952379 vs actual: 2.000000
#
# prediction: 1.847112 vs actual: 2.000000
#
# prediction: 1.200748 vs actual: 1.000000
#
# prediction: 1.952379 vs actual: 2.000000
#
# prediction: 1.264760 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.002012 vs actual: 2.000000
#
# prediction: 0.846093 vs actual: 1.000000
#
# prediction: 1.170144 vs actual: 1.000000
#
# prediction: 0.889191 vs actual: 1.000000
#
# prediction: 0.647905 vs actual: 1.000000
#
# prediction: 0.534165 vs actual: 1.000000
#
# prediction: 0.666085 vs actual: 1.000000
#
# prediction: 2.005357 vs actual: 2.000000
#
# prediction: 1.780031 vs actual: 2.000000
#
# prediction: 0.654213 vs actual: 1.000000
#
# prediction: 1.630051 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 2.509871 vs actual: 2.000000
#
# prediction: 0.705041 vs actual: 1.000000
#
# prediction: 1.350221 vs actual: 1.000000
#
# prediction: 0.077228 vs actual: 0.000000
#
# prediction: 0.555516 vs actual: 1.000000
#
# prediction: 1.207750 vs actual: 1.000000
#
# prediction: 0.056198 vs actual: 0.000000
#
# prediction: 0.036319 vs actual: 0.000000
#
# prediction: 0.560818 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.009007 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.959020 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.078062 vs actual: 1.000000
#
# prediction: 0.369067 vs actual: 0.000000
#
# prediction: 0.420772 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.048676 vs actual: 1.000000
#
# prediction: 0.190968 vs actual: 0.000000
#
# prediction: 0.534165 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.196929 vs actual: 0.000000
#
# prediction: 0.036319 vs actual: 0.000000
#
# prediction: 1.402112 vs actual: 1.000000
#
# prediction: 2.949160 vs actual: 3.000000
#
# prediction: 1.455193 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.021911 vs actual: 0.000000
#
# prediction: 1.324060 vs actual: 1.000000
#
# prediction: 0.458283 vs actual: 1.000000
#
# prediction: 0.595790 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 3.070758 vs actual: 3.000000
#
# prediction: 2.012025 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 3.179429 vs actual: 3.000000
#
# prediction: 0.490745 vs actual: 1.000000
#
# prediction: 0.274884 vs actual: 1.000000
#
# prediction: 1.090716 vs actual: 1.000000
#
# prediction: 1.327136 vs actual: 1.000000
#
# prediction: 0.939744 vs actual: 1.000000
#
# prediction: 1.304596 vs actual: 1.000000
#
# prediction: 0.711414 vs actual: 1.000000
#
# prediction: 2.942466 vs actual: 4.000000
#
# prediction: 2.249014 vs actual: 4.000000
#
# prediction: 0.900259 vs actual: 2.000000
#
# prediction: 0.077228 vs actual: 0.000000
#
# prediction: 0.889513 vs actual: 1.000000
#
# prediction: 0.500174 vs actual: 1.000000
#
# prediction: 0.500174 vs actual: 1.000000
#
# prediction: 1.152308 vs actual: 2.000000
#
# prediction: 0.500174 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 1.863312 vs actual: 2.000000
#
# prediction: 0.891741 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.728581 vs actual: 1.000000
#
# prediction: 0.281192 vs actual: 1.000000
#
# prediction: 0.150059 vs actual: 1.000000
#
# prediction: 0.114274 vs actual: 0.000000
#
# prediction: 0.868198 vs actual: 1.000000
#
# prediction: 1.703775 vs actual: 2.000000
#
# prediction: 0.881386 vs actual: 1.000000
#
# prediction: 1.942233 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.898285 vs actual: 2.000000
#
# prediction: 0.666111 vs actual: 1.000000
#
# prediction: 0.666085 vs actual: 1.000000
#
# prediction: 1.244632 vs actual: 1.000000
#
# prediction: 0.369093 vs actual: 1.000000
#
# prediction: 1.475378 vs actual: 1.000000
#
# prediction: 0.196929 vs actual: 0.000000
#
# prediction: 0.021911 vs actual: 0.000000
#
# prediction: 0.240893 vs actual: 0.000000
#
# prediction: 0.000000 vs actual: 0.000000
#
# prediction: 0.641648 vs actual: 1.000000
#
# prediction: 0.394933 vs actual: 0.000000
#
# prediction: 0.507665 vs actual: 1.000000
#
# prediction: 2.437630 vs actual: 2.000000
#
# prediction: 1.345187 vs actual: 1.000000
#
# prediction: 3.473246 vs actual: 4.000000
#
# prediction: 0.119575 vs actual: 0.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 1.589498 vs actual: 2.000000
#
# prediction: 0.641028 vs actual: 1.000000
#
# prediction: 0.766640 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.964322 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 1.000000
#
# prediction: 1.681764 vs actual: 3.000000
#
# prediction: 2.587707 vs actual: 3.000000
#
# prediction: 1.713814 vs actual: 2.000000
#
# prediction: 0.000000 vs actual: 1.000000
#
# prediction: 0.266759 vs actual: 1.000000
#
# prediction: 0.555516 vs actual: 1.000000
#
# prediction: 0.474136 vs actual: 1.000000
#
# prediction: 1.833515 vs actual: 2.000000
#
# prediction: 1.272572 vs actual: 1.000000
#
# prediction: 1.476545 vs actual: 1.000000
#
# prediction: 0.000000 vs actual: 1.000000
#
# prediction: 0.876364 vs actual: 1.000000
#
# prediction: 2.801992 vs actual: 4.000000
#
# prediction: 0.346749 vs actual: 1.000000
#
# prediction: 0.487015 vs actual: 1.000000
#
# prediction: 1.554756 vs actual: 2.000000
#
# prediction: 1.733130 vs actual: 2.000000
#
# prediction: 1.573698 vs actual: 2.000000
#
# prediction: 1.150571 vs actual: 1.000000
#
# prediction: 0.563361 vs actual: 1.000000
#
# prediction: 1.919504 vs actual: 2.000000
#
# prediction: 1.595859 vs actual: 2.000000
#
# prediction: 0.594692 vs actual: 1.000000
#
# prediction: 0.936382 vs actual: 2.000000
#
# prediction: 0.921975 vs actual: 2.000000
#
# prediction: 1.405242 vs actual: 2.000000
#
# prediction: 1.304687 vs actual: 2.000000
#
# prediction: 1.373170 vs actual: 2.000000
#
# prediction: 1.304687 vs actual: 2.000000
#
# prediction: 0.964637 vs actual: 2.000000
#
# Accuracy: 0.29411764705882354

# %%
#Current accuracy values suggest underfitting as both training and testing accuracy are low
